# %% [markdown]
# Defining what a planet/start object is
# Each body constains
# . mass
# . position (x,y)
# . velocity
# . acceleration
# should store previous positions since I want to trail the orbits

# %%
#libraries
import numpy as np

# %%
class Body: #just to store state of the object
    def __init__(self, name, mass, position, velocity, color = "white", size = 5):
        self.name = name
        self.mass = mass
        self.position = np.array(position, dtype= float)
        self.velocity = np.array(velocity, dtype=float)
        # acceleration computed during simulation so here we just initialise it
        self.acceleration = np.zeros(2)
        #for visualisation purposes
        self.color = color
        self.size = size
        # to store previous positions for orbit trails
        self.trail = []
        # do methods for acc, vel and position update
